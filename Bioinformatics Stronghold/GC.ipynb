# %%
with open('rosalind_gc.txt', 'rt') as file:
    dic = {}
    FASTA_id = None
    for line in file:
        line = line.strip()
        if line.startswith(">"):
            FASTA_id = line
            dic[FASTA_id] = ""
        else:
            dic[FASTA_id] += line

print(dic)
# Out:
# {'>Rosalind_7114': '...', '>Rosalind_3655': '...', '>Rosalind_6388': '...', '>Rosalind_2065': '...', '>Rosalind_5872': '...', '>Rosalind_9246': '...', '>Rosalind_5213': '...', '>Rosalind_6138': '...'}

# %%
for key in dic.keys():
    gc_count = 0
    for letter in dic[key]:
        gc_count += 1
    gc_content = gc_count/len(dic[key])

# %%
            for letter in line:
                if letter == "G" or letter == "C":
                    gc_count += 1
            gc_content = gc_count/len(line)
            #print(gc_content)
        if highest_gc < gc_content:
            saved_id = FASTA_id
            #print(saved_id)
            highest_gc == gc_content
print(saved_id,highest_gc)
