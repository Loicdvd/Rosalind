# %%
with open("rosalind_hamm.txt", "rt") as file:
    s = file.readline().strip()
    j = file.readline().strip()
print(s)
print(j)
count = 0
for i in range(min(len(s),len(j))):
    if s[i] != j[i]:
        count +=1
Hamm_distance = count
print(Hamm_distance)
# Out:
# ...
# ...
# 478
