# %%
with open("rosalind_rna.txt", "rt") as file:
    s = file.readline().strip()
print(s)
# Out:
# ...

# %%
with open('output.txt', 'w') as file2:
    file2.write("")

o = ""
with open('output.txt', 'a') as file2:
    for i in range(len(s)):
        if s[i] == "T":
            o += "U"
        else :
            o += s[i]
    print(o)
    file2.write(o)
# Out:
# ...
