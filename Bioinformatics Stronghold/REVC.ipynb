# %%
with open("rosalind_revc.txt", "rt") as file:
    s = file.readline().strip()
print(s)
# Out:
# ...

# %%
with open('output_REVC.txt', 'w') as file2:
    file2.write("")


o = ""
with open('output_REVC.txt', 'a') as file2:
    for i in range(len(s)-1,-1,-1):
        if s[i] == "A":
            o += "T"
        elif s[i] == "C":
            o += "G"
        elif s[i] == "G":
            o += "C"
        elif s[i] == "T":
            o += "A"
    print(o)
    file2.write(o)
# Out:
# ...
